# %%
pip install pandas
# Out:
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 672.4 kB/s eta 0:00:14
#    -- ------------------------------------- 0.5/9.7 MB 672.4 kB/s eta 0:00:14
#    --- ------------------------------------ 0.8/9.7 MB 645.7 kB/s eta 0:00:14
#    ---- ----------------------------------- 1.0/9.7 MB 728.1 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.7 MB 772.2 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.3/9.7 MB 772.2 kB/s eta 0:00:11
#    ------ --------------------------------- 1.6/9.7 MB 813.9 kB/s eta 0:00:11
#    ------- -------------------------------- 1.8/9.7 MB 832.2 kB/s eta 0:00:10
# ...

# %%
import pandas as pd
# with open (...)
df = pd.read_csv("../data/clean/weather_data.csv")
df.head(1)
# Out:
#              city          datetime  temperature  precipitation  wind_speed  \
# 0  Madrid Barajas  2026-01-01T00:00          1.5            0.0         3.0
#
#    wind_direction
# 0             346

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp313-cp313-win_amd64.whl.metadata (116 kB)
# ...
#   Using cached pillow-12.1.1-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp313-cp313-win_amd64.whl (2.3 MB)
# ...
# Using cached pillow-12.1.1-cp313-cp313-win_amd64.whl (7.0 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
# ...

# %%
import matplotlib.pyplot as plt
temperatura = df["temperature"]

plt.figure(figsize=(10,6))
temperatura.plot(kind="line")

plt.title("Temperatura en Madrid Barajas")
plt.xlabel("Registro")
plt.ylabel("Temperatura (°C)")

plt.show()

# %%
viento = df["wind_speed"]

plt.figure(figsize=(10,6))
viento.plot(kind="line")

plt.title("Velocidad del viento en Madrid Barajas")
plt.xlabel("Registro")
plt.ylabel("Velocidad viento")

plt.show()

# %%
precipitacion = df["precipitation"]

plt.figure(figsize=(10,6))
precipitacion.plot(kind="line")

plt.title("Precipitacion en Madrid Barajas")
plt.xlabel("Registro")
plt.ylabel("Precipitacion")

plt.show()
